# %% [markdown]
# # Chapter 21
#
# ## Structured Streaming: Basics

# %%
static = spark.read.json("gs://reddys-data-for-experimenting/activity-data/")
dataSchema = static.schema
static.count()
# Out:
# 6240991

# %%
from pyspark.sql.types import StructField, TimestampType
dataSchema.fields[1] = StructField("Creation_Time", TimestampType(), True)
static.printSchema()
print(dataSchema)
# Out:
# root
#  |-- Arrival_Time: long (nullable = true)
#  |-- Creation_Time: long (nullable = true)
#  |-- Device: string (nullable = true)
#  |-- Index: long (nullable = true)
#  |-- Model: string (nullable = true)
#  |-- User: string (nullable = true)
#  |-- gt: string (nullable = true)
#  |-- x: double (nullable = true)
#  |-- y: double (nullable = true)
#  |-- z: double (nullable = true)
#
# StructType(List(StructField(Arrival_Time,LongType,true),StructField(Creation_Time,TimestampType,true),StructField(Device,StringType,true),StructField(Index,LongType,true),StructField(Model,StringType,true),StructField(User,StringType,true),StructField(gt,StringType,true),StructField(x,DoubleType,true),StructField(y,DoubleType,true),StructField(z,DoubleType,true)))

# %% [markdown]
# ### Reading a stream

# %%
streaming = spark.readStream.schema(dataSchema).option("maxFilesPerTrigger", 1)\
  .json("gs://reddys-data-for-experimenting/activity-data/")

# %%
transformedStream = streaming.selectExpr("User", "gt", "Model")

# %%
transformedStreamWriter = transformedStream.writeStream \
    .option("checkpointLocation", "gs://reddys-data-for-experimenting/output/chkpnt") \
    .queryName("transformedStream")\
    .outputMode("append")\
    .start(path="gs://reddys-data-for-experimenting/output/streaming", format="parquet") 
    # .awaitTermination()

# %% [markdown]
# ### Monitoring your streams Application

# %%
transformedStreamWriter.status
# Out:
# {u'isDataAvailable': True,
#  u'isTriggerActive': False,
#  u'message': u'Processing new data'}

# %%
transformedStreamWriter.recentProgress
# Out:
# [{u'batchId': 0,
#   u'durationMs': {u'addBatch': 4722,
#    u'getBatch': 239,
#    u'getOffset': 1081,
#    u'queryPlanning': 60,
#    u'triggerExecution': 6874,
#    u'walCommit': 711},
#   u'id': u'9abb1cc1-5e13-4472-ae6b-eb0063f65ce2',
#   u'name': u'transformedStream',
#   u'numInputRows': 78012,
#   u'processedRowsPerSecond': 11343.899956376326,
#   u'runId': u'b208329b-1676-4851-9c0a-ab1d5b458bd5',
#   u'sink': {u'description': u'FileSink[gs://reddys-data-for-experimenting/output/streaming]'},
#   u'sources': [{u'description': u'FileStreamSource[gs://reddys-data-for-experimenting/activity-data]',
#     u'endOffset': {u'logOffset': 0},
#     u'numInputRows': 78012,
#     u'processedRowsPerSecond': 11343.899956376326,
#     u'startOffset': None}],
#   u'stateOperators': [],
#   u'timestamp': u'2019-10-06T15:46:24.930Z'},
#  {u'batchId': 1,
#   u'durationMs': {u'addBatch': 7114,
#    u'getBatch': 134,
#    u'getOffset': 827,
#    u'queryPlanning': 27,
#    u'triggerExecution': 9443,
#    u'walCommit': 1336},
#   u'id': u'9abb1cc1-5e13-4472-ae6b-eb0063f65ce2',
#   u'inputRowsPerSecond': 10173.57850808555,
#   u'name': u'transformedStream',
#   u'numInputRows': 78011,
#   u'processedRowsPerSecond': 8261.251720851425,
#   u'runId': u'b208329b-1676-4851-9c0a-ab1d5b458bd5',
#   u'sink': {u'description': u'FileSink[gs://reddys-data-for-experimenting/output/streaming]'},
#   u'sources': [{u'description': u'FileStreamSource[gs://reddys-data-for-experimenting/activity-data]',
#     u'endOffset': {u'logOffset': 1},
#     u'inputRowsPerSecond': 10173.57850808555,
#     u'numInputRows': 78011,
#     u'processedRowsPerSecond': 8261.251720851425,
#     u'startOffset': {u'logOffset': 0}}],
#   u'stateOperators': [],
#   u'timestamp': u'2019-10-06T15:46:32.598Z'},
#  {u'batchId': 2,
#   u'durationMs': {u'addBatch': 2316,
#    u'getBatch': 232,
#    u'getOffset': 677,
#    u'queryPlanning': 14,
#    u'triggerExecution': 3973,
#    u'walCommit': 733},
#   u'id': u'9abb1cc1-5e13-4472-ae6b-eb0063f65ce2',
#   u'inputRowsPerSecond': 7648.985194626925,
#   u'name': u'transformedStream',
#   u'numInputRows': 78012,
#   u'processedRowsPerSecond': 19635.539894286434,
#   u'runId': u'b208329b-1676-4851-9c0a-ab1d5b458bd5',
#   u'sink': {u'description': u'FileSink[gs://reddys-data-for-experimenting/output/streaming]'},
#   u'sources': [{u'description': u'FileStreamSource[gs://reddys-data-for-experimenting/activity-data]',
#     u'endOffset': {u'logOffset': 2},
#     u'inputRowsPerSecond': 7648.985194626925,
#     u'numInputRows': 78012,
#     u'processedRowsPerSecond': 19635.539894286434,
#     u'startOffset': {u'logOffset': 1}}],
#   u'stateOperators': [],
#   u'timestamp': u'2019-10-06T15:46:42.797Z'},
#  {u'batchId': 3,
#   u'durationMs': {u'addBatch': 1788,
#    u'getBatch': 143,
#    u'getOffset': 765,
#    u'queryPlanning': 12,
#    u'triggerExecution': 3492,
#    u'walCommit': 781},
#   u'id': u'9abb1cc1-5e13-4472-ae6b-eb0063f65ce2',
#   u'inputRowsPerSecond': 16805.68720379147,
#   u'name': u'transformedStream',
#   u'numInputRows': 78012,
#   u'processedRowsPerSecond': 22327.418431597023,
#   u'runId': u'b208329b-1676-4851-9c0a-ab1d5b458bd5',
#   u'sink': {u'description': u'FileSink[gs://reddys-data-for-experimenting/output/streaming]'},
#   u'sources': [{u'description': u'FileStreamSource[gs://reddys-data-for-experimenting/activity-data]',
#     u'endOffset': {u'logOffset': 3},
#     u'inputRowsPerSecond': 16805.68720379147,
#     u'numInputRows': 78012,
#     u'processedRowsPerSecond': 22327.418431597023,
#     u'startOffset': {u'logOffset': 2}}],
#   u'stateOperators': [],
#   u'timestamp': u'2019-10-06T15:46:47.439Z'},
#  {u'batchId': 4,
#   u'durationMs': {u'addBatch': 1746,
#    u'getBatch': 137,
#    u'getOffset': 696,
#    u'queryPlanning': 12,
#    u'triggerExecution': 3319,
#    u'walCommit': 728},
#   u'id': u'9abb1cc1-5e13-4472-ae6b-eb0063f65ce2',
#   u'inputRowsPerSecond': 18570.340395144016,
#   u'name': u'transformedStream',
#   u'numInputRows': 78014,
#   u'processedRowsPerSecond': 23505.272672491716,
#   u'runId': u'b208329b-1676-4851-9c0a-ab1d5b458bd5',
#   u'sink': {u'description': u'FileSink[gs://reddys-data-for-experimenting/output/streaming]'},
#   u'sources': [{u'description': u'FileStreamSource[gs://reddys-data-for-experimenting/activity-data]',
#     u'endOffset': {u'logOffset': 4},
#     u'inputRowsPerSecond': 18570.340395144016,
#     u'numInputRows': 78014,
#     u'processedRowsPerSecond': 23505.272672491716,
#     u'startOffset': {u'logOffset': 3}}],
#   u'stateOperators': [],
#   u'timestamp': u'2019-10-06T15:46:51.640Z'},
#  {u'batchId': 5,
#   u'durationMs': {u'addBatch': 1614,
#    u'getBatch': 164,
#    u'getOffset': 704,
#    u'queryPlanning': 25,
#    u'triggerExecution': 3197,
#    u'walCommit': 687},
#   u'id': u'9abb1cc1-5e13-4472-ae6b-eb0063f65ce2',
#   u'inputRowsPerSecond': 19532.799198798195,
#   u'name': u'transformedStream',
#   u'numInputRows': 78014,
#   u'processedRowsPerSecond': 24402.252111354395,
#   u'runId': u'b208329b-1676-4851-9c0a-ab1d5b458bd5',
#   u'sink': {u'description': u'FileSink[gs://reddys-data-for-experimenting/output/streaming]'},
#   u'sources': [{u'description': u'FileStreamSource[gs://reddys-data-for-experimenting/activity-data]',
#     u'endOffset': {u'logOffset': 5},
#     u'inputRowsPerSecond': 19532.799198798195,
#     u'numInputRows': 78014,
#     u'processedRowsPerSecond': 24402.252111354395,
#     u'startOffset': {u'logOffset': 4}}],
#   u'stateOperators': [],
#   u'timestamp': u'2019-10-06T15:46:55.634Z'},
#  {u'batchId': 6,
#   u'durationMs': {u'addBatch': 1590,
#    u'getBatch': 120,
#    u'getOffset': 726,
#    u'queryPlanning': 11,
#    u'triggerExecution': 3130,
#    u'walCommit': 681},
#   u'id': u'9abb1cc1-5e13-4472-ae6b-eb0063f65ce2',
#   u'inputRowsPerSecond': 20492.25111636459,
#   u'name': u'transformedStream',
#   u'numInputRows': 78014,
#   u'processedRowsPerSecond': 24916.640051101887,
#   u'runId': u'b208329b-1676-4851-9c0a-ab1d5b458bd5',
#   u'sink': {u'description': u'FileSink[gs://reddys-data-for-experimenting/output/streaming]'},
#   u'sources': [{u'description': u'FileStreamSource[gs://reddys-data-for-experimenting/activity-data]',
#     u'endOffset': {u'logOffset': 6},
#     u'inputRowsPerSecond': 20492.25111636459,
#     u'numInputRows': 78014,
#     u'processedRowsPerSecond': 24916.640051101887,
#     u'startOffset': {u'logOffset': 5}}],
#   u'stateOperators': [],
#   u'timestamp': u'2019-10-06T15:46:59.441Z'},
#  {u'batchId': 7,
#   u'durationMs': {u'addBatch': 2200,
#    u'getBatch': 148,
#    u'getOffset': 651,
#    u'queryPlanning': 12,
#    u'triggerExecution': 3692,
#    u'walCommit': 680},
#   u'id': u'9abb1cc1-5e13-4472-ae6b-eb0063f65ce2',
#   u'inputRowsPerSecond': 20567.888215133138,
#   u'name': u'transformedStream',
#   u'numInputRows': 78014,
#   u'processedRowsPerSecond': 21124.830760898996,
#   u'runId': u'b208329b-1676-4851-9c0a-ab1d5b458bd5',
#   u'sink': {u'description': u'FileSink[gs://reddys-data-for-experimenting/output/streaming]'},
#   u'sources': [{u'description': u'FileStreamSource[gs://reddys-data-for-experimenting/activity-data]',
#     u'endOffset': {u'logOffset': 7},
#     u'inputRowsPerSecond': 20567.888215133138,
#     u'numInputRows': 78014,
#     u'processedRowsPerSecond': 21124.830760898996,
#     u'startOffset': {u'logOffset': 6}}],
#   u'stateOperators': [],
#   u'timestamp': u'2019-10-06T15:47:03.234Z'},
#  {u'batchId': 8,
#   u'durationMs': {u'addBatch': 1607,
#    u'getBatch': 125,
#    u'getOffset': 647,
#    u'queryPlanning': 11,
#    u'triggerExecution': 3156,
#    u'walCommit': 764},
#   u'id': u'9abb1cc1-5e13-4472-ae6b-eb0063f65ce2',
#   u'inputRowsPerSecond': 18049.745488199907,
#   u'name': u'transformedStream',
#   u'numInputRows': 78011,
#   u'processedRowsPerSecond': 24718.31432192649,
#   u'runId': u'b208329b-1676-4851-9c0a-ab1d5b458bd5',
#   u'sink': {u'description': u'FileSink[gs://reddys-data-for-experimenting/output/streaming]'},
#   u'sources': [{u'description': u'FileStreamSource[gs://reddys-data-for-experimenting/activity-data]',
#     u'endOffset': {u'logOffset': 8},
#     u'inputRowsPerSecond': 18049.745488199907,
#     u'numInputRows': 78011,
#     u'processedRowsPerSecond': 24718.31432192649,
#     u'startOffset': {u'logOffset': 7}}],
#   u'stateOperators': [],
#   u'timestamp': u'2019-10-06T15:47:07.556Z'},
#  {u'batchId': 9,
#   u'durationMs': {u'addBatch': 2053,
#    u'getBatch': 51,
#    u'getOffset': 1223,
#    u'queryPlanning': 15,
#    u'triggerExecution': 4079,
#    u'walCommit': 736},
#   u'id': u'9abb1cc1-5e13-4472-ae6b-eb0063f65ce2',
#   u'inputRowsPerSecond': 20540.810953133227,
#   u'name': u'transformedStream',
#   u'numInputRows': 78014,
#   u'processedRowsPerSecond': 19125.76611914685,
#   u'runId': u'b208329b-1676-4851-9c0a-ab1d5b458bd5',
#   u'sink': {u'description': u'FileSink[gs://reddys-data-for-experimenting/output/streaming]'},
#   u'sources': [{u'description': u'FileStreamSource[gs://reddys-data-for-experimenting/activity-data]',
#     u'endOffset': {u'logOffset': 9},
#     u'inputRowsPerSecond': 20540.810953133227,
#     u'numInputRows': 78014,
#     u'processedRowsPerSecond': 19125.76611914685,
#     u'startOffset': {u'logOffset': 8}}],
#   u'stateOperators': [],
#   u'timestamp': u'2019-10-06T15:47:11.354Z'},
#  {u'batchId': 10,
#   u'durationMs': {u'addBatch': 1707,
#    u'getBatch': 178,
#    u'getOffset': 724,
#    u'queryPlanning': 112,
#    u'triggerExecution': 3378,
#    u'walCommit': 656},
#   u'id': u'9abb1cc1-5e13-4472-ae6b-eb0063f65ce2',
#   u'inputRowsPerSecond': 16794.833153928957,
#   u'name': u'transformedStream',
#   u'numInputRows': 78012,
#   u'processedRowsPerSecond': 23094.138543516874,
#   u'runId': u'b208329b-1676-4851-9c0a-ab1d5b458bd5',
#   u'sink': {u'description': u'FileSink[gs://reddys-data-for-experimenting/output/streaming]'},
#   u'sources': [{u'description': u'FileStreamSource[gs://reddys-data-for-experimenting/activity-data]',
#     u'endOffset': {u'logOffset': 10},
#     u'inputRowsPerSecond': 16794.833153928957,
#     u'numInputRows': 78012,
#     u'processedRowsPerSecond': 23094.138543516874,
#     u'startOffset': {u'logOffset': 9}}],
#   u'stateOperators': [],
#   u'timestamp': u'2019-10-06T15:47:15.999Z'},
#  {u'batchId': 11,
#   u'durationMs': {u'addBatch': 1613,
#    u'getBatch': 135,
#    u'getOffset': 694,
#    u'queryPlanning': 24,
#    u'triggerExecution': 3261,
#    u'walCommit': 794},
#   u'id': u'9abb1cc1-5e13-4472-ae6b-eb0063f65ce2',
#   u'inputRowsPerSecond': 19508.37709427357,
#   u'name': u'transformedStream',
#   u'numInputRows': 78014,
#   u'processedRowsPerSecond': 23923.33639987734,
#   u'runId': u'b208329b-1676-4851-9c0a-ab1d5b458bd5',
#   u'sink': {u'description': u'FileSink[gs://reddys-data-for-experimenting/output/streaming]'},
#   u'sources': [{u'description': u'FileStreamSource[gs://reddys-data-for-experimenting/activity-data]',
#     u'endOffset': {u'logOffset': 11},
#     u'inputRowsPerSecond': 19508.37709427357,
#     u'numInputRows': 78014,
#     u'processedRowsPerSecond': 23923.33639987734,
#     u'startOffset': {u'logOffset': 10}}],
#   u'stateOperators': [],
#   u'timestamp': u'2019-10-06T15:47:19.998Z'},
#  {u'batchId': 12,
#   u'durationMs': {u'addBatch': 1544,
#    u'getBatch': 128,
#    u'getOffset': 678,
#    u'queryPlanning': 14,
#    u'triggerExecution': 3107,
#    u'walCommit': 741},
#   u'id': u'9abb1cc1-5e13-4472-ae6b-eb0063f65ce2',
#   u'inputRowsPerSecond': 20189.699792960662,
#   u'name': u'transformedStream',
#   u'numInputRows': 78013,
#   u'processedRowsPerSecond': 25108.78661087866,
#   u'runId': u'b208329b-1676-4851-9c0a-ab1d5b458bd5',
#   u'sink': {u'description': u'FileSink[gs://reddys-data-for-experimenting/output/streaming]'},
#   u'sources': [{u'description': u'FileStreamSource[gs://reddys-data-for-experimenting/activity-data]',
#     u'endOffset': {u'logOffset': 12},
#     u'inputRowsPerSecond': 20189.699792960662,
#     u'numInputRows': 78013,
#     u'processedRowsPerSecond': 25108.78661087866,
#     u'startOffset': {u'logOffset': 11}}],
#   u'stateOperators': [],
#   u'timestamp': u'2019-10-06T15:47:23.862Z'},
#  {u'batchId': 13,
#   u'durationMs': {u'addBatch': 1271,
#    u'getBatch': 113,
#    u'getOffset': 731,
#    u'queryPlanning': 17,
#    u'triggerExecution': 2798,
#    u'walCommit': 665},
#   u'id': u'9abb1cc1-5e13-4472-ae6b-eb0063f65ce2',
#   u'inputRowsPerSecond': 20660.22245762712,
#   u'name': u'transformedStream',
#   u'numInputRows': 78013,
#   u'processedRowsPerSecond': 27881.70121515368,
#   u'runId': u'b208329b-1676-4851-9c0a-ab1d5b458bd5',
#   u'sink': {u'description': u'FileSink[gs://reddys-data-for-experimenting/output/streaming]'},
#   u'sources': [{u'description': u'FileStreamSource[gs://reddys-data-for-experimenting/activity-data]',
#     u'endOffset': {u'logOffset': 13},
#     u'inputRowsPerSecond': 20660.22245762712,
#     u'numInputRows': 78013,
#     u'processedRowsPerSecond': 27881.70121515368,
#     u'startOffset': {u'logOffset': 12}}],
#   u'stateOperators': [],
#   u'timestamp': u'2019-10-06T15:47:27.638Z'},
#  {u'batchId': 14,
#   u'durationMs': {u'addBatch': 1529,
#    u'getBatch': 147,
#    u'getOffset': 671,
#    u'queryPlanning': 15,
#    u'triggerExecution': 3104,
#    u'walCommit': 742},
#   u'id': u'9abb1cc1-5e13-4472-ae6b-eb0063f65ce2',
#   u'inputRowsPerSecond': 22817.19801111436,
#   u'name': u'transformedStream',
#   u'numInputRows': 78012,
#   u'processedRowsPerSecond': 25132.731958762884,
#   u'runId': u'b208329b-1676-4851-9c0a-ab1d5b458bd5',
#   u'sink': {u'description': u'FileSink[gs://reddys-data-for-experimenting/output/streaming]'},
#   u'sources': [{u'description': u'FileStreamSource[gs://reddys-data-for-experimenting/activity-data]',
#     u'endOffset': {u'logOffset': 14},
#     u'inputRowsPerSecond': 22817.19801111436,
#     u'numInputRows': 78012,
#     u'processedRowsPerSecond': 25132.731958762884,
#     u'startOffset': {u'logOffset': 13}}],
#   u'stateOperators': [],
#   u'timestamp': u'2019-10-06T15:47:31.057Z'},
#  {u'batchId': 15,
#   u'durationMs': {u'addBatch': 1501,
#    u'getBatch': 121,
#    u'getOffset': 790,
#    u'queryPlanning': 10,
#    u'triggerExecution': 3098,
#    u'walCommit': 676},
#   u'id': u'9abb1cc1-5e13-4472-ae6b-eb0063f65ce2',
#   u'inputRowsPerSecond': 21112.58457374831,
#   u'name': u'transformedStream',
#   u'numInputRows': 78011,
#   u'processedRowsPerSecond': 25181.084570690768,
#   u'runId': u'b208329b-1676-4851-9c0a-ab1d5b458bd5',
#   u'sink': {u'description': u'FileSink[gs://reddys-data-for-experimenting/output/streaming]'},
#   u'sources': [{u'description': u'FileStreamSource[gs://reddys-data-for-experimenting/activity-data]',
#     u'endOffset': {u'logOffset': 15},
#     u'inputRowsPerSecond': 21112.58457374831,
#     u'numInputRows': 78011,
#     u'processedRowsPerSecond': 25181.084570690768,
#     u'startOffset': {u'logOffset': 14}}],
#   u'stateOperators': [],
#   u'timestamp': u'2019-10-06T15:47:34.752Z'},
#  {u'batchId': 16,
#   u'durationMs': {u'addBatch': 1432,
#    u'getBatch': 120,
#    u'getOffset': 800,
#    u'queryPlanning': 21,
#    u'triggerExecution': 3035,
#    u'walCommit': 661},
#   u'id': u'9abb1cc1-5e13-4472-ae6b-eb0063f65ce2',
#   u'inputRowsPerSecond': 20892.34065345474,
#   u'name': u'transformedStream',
#   u'numInputRows': 78012,
#   u'processedRowsPerSecond': 25704.118616144973,
#   u'runId': u'b208329b-1676-4851-9c0a-ab1d5b458bd5',
#   u'sink': {u'description': u'FileSink[gs://reddys-data-for-experimenting/output/streaming]'},
#   u'sources': [{u'description': u'FileStreamSource[gs://reddys-data-for-experimenting/activity-data]',
#     u'endOffset': {u'logOffset': 16},
#     u'inputRowsPerSecond': 20892.34065345474,
#     u'numInputRows': 78012,
#     u'processedRowsPerSecond': 25704.118616144973,
#     u'startOffset': {u'logOffset': 15}}],
#   u'stateOperators': [],
#   u'timestamp': u'2019-10-06T15:47:38.486Z'},
#  {u'batchId': 17,
#   u'durationMs': {u'addBatch': 1380,
#    u'getBatch': 110,
#    u'getOffset': 690,
#    u'queryPlanning': 8,
#    u'triggerExecution': 2824,
#    u'walCommit': 635},
#   u'id': u'9abb1cc1-5e13-4472-ae6b-eb0063f65ce2',
#   u'inputRowsPerSecond': 21285.675306957706,
#   u'name': u'transformedStream',
#   u'numInputRows': 78012,
#   u'processedRowsPerSecond': 27624.645892351276,
#   u'runId': u'b208329b-1676-4851-9c0a-ab1d5b458bd5',
#   u'sink': {u'description': u'FileSink[gs://reddys-data-for-experimenting/output/streaming]'},
#   u'sources': [{u'description': u'FileStreamSource[gs://reddys-data-for-experimenting/activity-data]',
#     u'endOffset': {u'logOffset': 17},
#     u'inputRowsPerSecond': 21285.675306957706,
#     u'numInputRows': 78012,
#     u'processedRowsPerSecond': 27624.645892351276,
#     u'startOffset': {u'logOffset': 16}}],
#   u'stateOperators': [],
#   u'timestamp': u'2019-10-06T15:47:42.151Z'},
#  {u'batchId': 18,
#   u'durationMs': {u'addBatch': 1507,
#    u'getBatch': 155,
#    u'getOffset': 659,
#    u'queryPlanning': 10,
#    u'triggerExecution': 3133,
#    u'walCommit': 799},
#   u'id': u'9abb1cc1-5e13-4472-ae6b-eb0063f65ce2',
#   u'inputRowsPerSecond': 22301.886792452828,
#   u'name': u'transformedStream',
#   u'numInputRows': 78012,
#   u'processedRowsPerSecond': 24900.09575486754,
#   u'runId': u'b208329b-1676-4851-9c0a-ab1d5b458bd5',
#   u'sink': {u'description': u'FileSink[gs://reddys-data-for-experimenting/output/streaming]'},
#   u'sources': [{u'description': u'FileStreamSource[gs://reddys-data-for-experimenting/activity-data]',
#     u'endOffset': {u'logOffset': 18},
#     u'inputRowsPerSecond': 22301.886792452828,
#     u'numInputRows': 78012,
#     u'processedRowsPerSecond': 24900.09575486754,
#     u'startOffset': {u'logOffset': 17}}],
#   u'stateOperators': [],
#   u'timestamp': u'2019-10-06T15:47:45.649Z'},
#  {u'batchId': 19,
#   u'durationMs': {u'addBatch': 2039,
#    u'getBatch': 51,
#    u'getOffset': 1311,
#    u'queryPlanning': 14,
#    u'triggerExecution': 4138,
#    u'walCommit': 723},
#   u'id': u'9abb1cc1-5e13-4472-ae6b-eb0063f65ce2',
#   u'inputRowsPerSecond': 21176.43865363735,
#   u'name': u'transformedStream',
#   u'numInputRows': 78014,
#   u'processedRowsPerSecond': 18853.069115514743,
#   u'runId': u'b208329b-1676-4851-9c0a-ab1d5b458bd5',
#   u'sink': {u'description': u'FileSink[gs://reddys-data-for-experimenting/output/streaming]'},
#   u'sources': [{u'description': u'FileStreamSource[gs://reddys-data-for-experimenting/activity-data]',
#     u'endOffset': {u'logOffset': 19},
#     u'inputRowsPerSecond': 21176.43865363735,
#     u'numInputRows': 78014,
#     u'processedRowsPerSecond': 18853.069115514743,
#     u'startOffset': {u'logOffset': 18}}],
#   u'stateOperators': [],
#   u'timestamp': u'2019-10-06T15:47:49.333Z'},
#  {u'batchId': 20,
#   u'durationMs': {u'addBatch': 1595,
#    u'getBatch': 113,
#    u'getOffset': 670,
#    u'queryPlanning': 14,
#    u'triggerExecution': 3023,
#    u'walCommit': 630},
#   u'id': u'9abb1cc1-5e13-4472-ae6b-eb0063f65ce2',
#   u'inputRowsPerSecond': 15943.592887798897,
#   u'name': u'transformedStream',
#   u'numInputRows': 78012,
#   u'processedRowsPerSecond': 25806.15282831624,
#   u'runId': u'b208329b-1676-4851-9c0a-ab1d5b458bd5',
#   u'sink': {u'description': u'FileSink[gs://reddys-data-for-experimenting/output/streaming]'},
#   u'sources': [{u'description': u'FileStreamSource[gs://reddys-data-for-experimenting/activity-data]',
#     u'endOffset': {u'logOffset': 20},
#     u'inputRowsPerSecond': 15943.592887798897,
#     u'numInputRows': 78012,
#     u'processedRowsPerSecond': 25806.15282831624,
#     u'startOffset': {u'logOffset': 19}}],
#   u'stateOperators': [],
#   u'timestamp': u'2019-10-06T15:47:54.226Z'},
#  {u'batchId': 21,
#   u'durationMs': {u'addBatch': 1358,
#    u'getBatch': 128,
#    u'getOffset': 668,
#    u'queryPlanning': 10,
#    u'triggerExecution': 2987,
#    u'walCommit': 823},
#   u'id': u'9abb1cc1-5e13-4472-ae6b-eb0063f65ce2',
#   u'inputRowsPerSecond': 21527.041942604857,
#   u'name': u'transformedStream',
#   u'numInputRows': 78014,
#   u'processedRowsPerSecond': 26117.843990626046,
#   u'runId': u'b208329b-1676-4851-9c0a-ab1d5b458bd5',
#   u'sink': {u'description': u'FileSink[gs://reddys-data-for-experimenting/output/streaming]'},
#   u'sources': [{u'description': u'FileStreamSource[gs://reddys-data-for-experimenting/activity-data]',
#     u'endOffset': {u'logOffset': 21},
#     u'inputRowsPerSecond': 21527.041942604857,
#     u'numInputRows': 78014,
#     u'processedRowsPerSecond': 26117.843990626046,
#     u'startOffset': {u'logOffset': 20}}],
#   u'stateOperators': [],
#   u'timestamp': u'2019-10-06T15:47:57.850Z'},
#  {u'batchId': 22,
#   u'durationMs': {u'addBatch': 2968,
#    u'getBatch': 124,
#    u'getOffset': 657,
#    u'queryPlanning': 10,
#    u'triggerExecution': 4449,
#    u'walCommit': 689},
#   u'id': u'9abb1cc1-5e13-4472-ae6b-eb0063f65ce2',
#   u'inputRowsPerSecond': 21198.91304347826,
#   u'name': u'transformedStream',
#   u'numInputRows': 78012,
#   u'processedRowsPerSecond': 17534.726904922456,
#   u'runId': u'b208329b-1676-4851-9c0a-ab1d5b458bd5',
#   u'sink': {u'description': u'FileSink[gs://reddys-data-for-experimenting/output/streaming]'},
#   u'sources': [{u'description': u'FileStreamSource[gs://reddys-data-for-experimenting/activity-data]',
#     u'endOffset': {u'logOffset': 22},
#     u'inputRowsPerSecond': 21198.91304347826,
#     u'numInputRows': 78012,
#     u'processedRowsPerSecond': 17534.726904922456,
#     u'startOffset': {u'logOffset': 21}}],
#   u'stateOperators': [],
#   u'timestamp': u'2019-10-06T15:48:01.530Z'},
#  {u'batchId': 23,
#   u'durationMs': {u'addBatch': 1389,
#    u'getBatch': 113,
#    u'getOffset': 832,
#    u'queryPlanning': 9,
#    u'triggerExecution': 3154,
#    u'walCommit': 810},
#   u'id': u'9abb1cc1-5e13-4472-ae6b-eb0063f65ce2',
#   u'inputRowsPerSecond': 15245.651749071721,
#   u'name': u'transformedStream',
#   u'numInputRows': 78012,
#   u'processedRowsPerSecond': 24734.30564362714,
#   u'runId': u'b208329b-1676-4851-9c0a-ab1d5b458bd5',
#   u'sink': {u'description': u'FileSink[gs://reddys-data-for-experimenting/output/streaming]'},
#   u'sources': [{u'description': u'FileStreamSource[gs://reddys-data-for-experimenting/activity-data]',
#     u'endOffset': {u'logOffset': 23},
#     u'inputRowsPerSecond': 15245.651749071721,
#     u'numInputRows': 78012,
#     u'processedRowsPerSecond': 24734.30564362714,
#     u'startOffset': {u'logOffset': 22}}],
#   u'stateOperators': [],
#   u'timestamp': u'2019-10-06T15:48:06.647Z'},
#  {u'batchId': 24,
#   u'durationMs': {u'addBatch': 1428,
#    u'getBatch': 152,
#    u'getOffset': 667,
#    u'queryPlanning': 10,
#    u'triggerExecution': 2985,
#    u'walCommit': 728},
#   u'id': u'9abb1cc1-5e13-4472-ae6b-eb0063f65ce2',
#   u'inputRowsPerSecond': 19952.42966751918,
#   u'name': u'transformedStream',
#   u'numInputRows': 78014,
#   u'processedRowsPerSecond': 26135.34338358459,
#   u'runId': u'b208329b-1676-4851-9c0a-ab1d5b458bd5',
#   u'sink': {u'description': u'FileSink[gs://reddys-data-for-experimenting/output/streaming]'},
#   u'sources': [{u'description': u'FileStreamSource[gs://reddys-data-for-experimenting/activity-data]',
#     u'endOffset': {u'logOffset': 24},
#     u'inputRowsPerSecond': 19952.42966751918,
#     u'numInputRows': 78014,
#     u'processedRowsPerSecond': 26135.34338358459,
#     u'startOffset': {u'logOffset': 23}}],
#   u'stateOperators': [],
#   u'timestamp': u'2019-10-06T15:48:10.557Z'},
#  {u'batchId': 25,
#   u'durationMs': {u'addBatch': 1279,
#    u'getBatch': 140,
#    u'getOffset': 710,
#    u'queryPlanning': 10,
#    u'triggerExecution': 2822,
#    u'walCommit': 681},
#   u'id': u'9abb1cc1-5e13-4472-ae6b-eb0063f65ce2',
#   u'inputRowsPerSecond': 21919.35937060972,
#   u'name': u'transformedStream',
#   u'numInputRows': 78011,
#   u'processedRowsPerSecond': 27643.86959603118,
#   u'runId': u'b208329b-1676-4851-9c0a-ab1d5b458bd5',
#   u'sink': {u'description': u'FileSink[gs://reddys-data-for-experimenting/output/streaming]'},
#   u'sources': [{u'description': u'FileStreamSource[gs://reddys-data-for-experimenting/activity-data]',
#     u'endOffset': {u'logOffset': 25},
#     u'inputRowsPerSecond': 21919.35937060972,
#     u'numInputRows': 78011,
#     u'processedRowsPerSecond': 27643.86959603118,
#     u'startOffset': {u'logOffset': 24}}],
#   u'stateOperators': [],
#   u'timestamp': u'2019-10-06T15:48:14.116Z'},
#  {u'batchId': 26,
#   u'durationMs': {u'addBatch': 1459,
#    u'getBatch': 138,
#    u'getOffset': 621,
#    u'queryPlanning': 9,
#    u'triggerExecution': 2878,
#    u'walCommit': 649},
#   u'id': u'9abb1cc1-5e13-4472-ae6b-eb0063f65ce2',
#   u'inputRowsPerSecond': 22757.292882147023,
#   u'name': u'transformedStream',
#   u'numInputRows': 78012,
#   u'processedRowsPerSecond': 27106.32383599722,
#   u'runId': u'b208329b-1676-4851-9c0a-ab1d5b458bd5',
#   u'sink': {u'description': u'FileSink[gs://reddys-data-for-experimenting/output/streaming]'},
#   u'sources': [{u'description': u'FileStreamSource[gs://reddys-data-for-experimenting/activity-data]',
#     u'endOffset': {u'logOffset': 26},
#     u'inputRowsPerSecond': 22757.292882147023,
#     u'numInputRows': 78012,
#     u'processedRowsPerSecond': 27106.32383599722,
#     u'startOffset': {u'logOffset': 25}}],
#   u'stateOperators': [],
#   u'timestamp': u'2019-10-06T15:48:17.544Z'},
#  {u'batchId': 27,
#   u'durationMs': {u'addBatch': 1335,
#    u'getBatch': 112,
#    u'getOffset': 601,
#    u'queryPlanning': 9,
#    u'triggerExecution': 2769,
#    u'walCommit': 711},
#   u'id': u'9abb1cc1-5e13-4472-ae6b-eb0063f65ce2',
#   u'inputRowsPerSecond': 22149.914821124363,
#   u'name': u'transformedStream',
#   u'numInputRows': 78012,
#   u'processedRowsPerSecond': 28173.34777898158,
#   u'runId': u'b208329b-1676-4851-9c0a-ab1d5b458bd5',
#   u'sink': {u'description': u'FileSink[gs://reddys-data-for-experimenting/output/streaming]'},
#   u'sources': [{u'description': u'FileStreamSource[gs://reddys-data-for-experimenting/activity-data]',
#     u'endOffset': {u'logOffset': 27},
#     u'inputRowsPerSecond': 22149.914821124363,
#     u'numInputRows': 78012,
#     u'processedRowsPerSecond': 28173.34777898158,
#     u'startOffset': {u'logOffset': 26}}],
#   u'stateOperators': [],
#   u'timestamp': u'2019-10-06T15:48:21.066Z'},
#  {u'batchId': 28,
#   u'durationMs': {u'addBatch': 1296,
#    u'getBatch': 123,
#    u'getOffset': 645,
#    u'queryPlanning': 13,
#    u'triggerExecution': 2818,
#    u'walCommit': 738},
#   u'id': u'9abb1cc1-5e13-4472-ae6b-eb0063f65ce2',
#   u'inputRowsPerSecond': 22870.712401055407,
#   u'name': u'transformedStream',
#   u'numInputRows': 78012,
#   u'processedRowsPerSecond': 27673.643135863782,
#   u'runId': u'b208329b-1676-4851-9c0a-ab1d5b458bd5',
#   u'sink': {u'description': u'FileSink[gs://reddys-data-for-experimenting/output/streaming]'},
#   u'sources': [{u'description': u'FileStreamSource[gs://reddys-data-for-experimenting/activity-data]',
#     u'endOffset': {u'logOffset': 28},
#     u'inputRowsPerSecond': 22870.712401055407,
#     u'numInputRows': 78012,
#     u'processedRowsPerSecond': 27673.643135863782,
#     u'startOffset': {u'logOffset': 27}}],
#   u'stateOperators': [],
#   u'timestamp': u'2019-10-06T15:48:24.477Z'}]

# %% [markdown]
# ### Validating if the stream is working as expected

# %%
spark.streams.active

# %%
staticTransformedData = spark.read.format("parquet").load("gs://reddys-data-for-experimenting/output/streaming")

# %%
staticTransformedData.printSchema()
# Out:
# root
#  |-- User: string (nullable = true)
#  |-- gt: string (nullable = true)
#  |-- Model: string (nullable = true)

# %%
staticTransformedData.count()
# Out:
# 6240991

# %%
staticTransformedData.describe().show()
# Out:
# +-------+-------+-------+-------+
# |summary|   User|     gt|  Model|
# +-------+-------+-------+-------+
# |  count|6240991|6240991|6240991|
# |   mean|   null|   null|   null|
# | stddev|   null|   null|   null|
# |    min|      a|   bike| nexus4|
# |    max|      i|   walk| nexus4|
# +-------+-------+-------+-------+

# %% [markdown]
# ### Summay:
#
# Input data statics meets output data stats with data fromat converted to `Parquet` and with some stateless transformation.
